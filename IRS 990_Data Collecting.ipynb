# %% [markdown]
# ## How to get IRS 900 Data - Author: Hang (Jessie) Le

# %% [markdown]
# There are some links that I found useful to understand about the data set and get the data from AWS
# 1. [AWS Data](https://s3.amazonaws.com/irs-form-990): This is the main links that contains all XML files on AWS S3 bucket
# 2. [Github tutorial](https://github.com/lecy/Open-Data-for-Nonprofit-Research): This link provides some guidance on how to get the data set with R
# 3. [The IRS 990 e-file dataset: getting to the chocolatey center of data deliciousness](https://appliednonprofitresearch.com/posts/2018/06/the-irs-990-e-file-dataset-getting-to-the-chocolatey-center-of-data-deliciousness/): This link provides a overall understanding of XML and Xpath
# 4. [Open Data for Nonprofit Research](https://nonprofit-open-data-collective.github.io/overview/): This link provides a collection of useful links to get data dictionary and how to get data using different programming languages.
# 5. [XML to Pandas dataframe](https://medium.com/@robertopreste/from-xml-to-pandas-dataframes-9292980b1c1c): This link provides guidances on transforming XML files into pandas dataframe for Python users.

# %% [markdown]
# ### Load Packages

# %%
# Importing all libraries for data processing
import os
import pandas as pd 
import csv 
import requests 
import xml.etree.ElementTree as ET
from lxml import etree
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# #### Getting all the index files
# We first want to see a list of the annual index files. Each of these files contains a list of all the e-filings available that year. I already used the result from a tutorial to get the overview about how many years that are available to download. You can check it [here](http://social-metrics.org/irs-990-e-file-data-part-1/)
# ![alt text](Index.PNG)
# There are both CSV and JSON format versions of each annual file. You can download the csv files of index data for specific year directly from your browser using this url: https://s3.amazonaws.com/irs-form-990/index_2014.csv. If you want to get index for another year, just modify the last part of the file. For example: index for 2015 will be https://s3.amazonaws.com/irs-form-990/index_2015.csv
#
# We will use csv index files for reference while for data collecting process, json files will be used.

# %%
# Importing required libraries for getting the data
import requests 
import json
url = 'https://s3.amazonaws.com/irs-form-990/index_2014.json' # Passing the url for the specific year you want to collect.
                                                              # In this example, I'm collecting data for 2014. 
f = requests.get(url)
data = f.json()

# %% [markdown]
# The data returned are in JSON format and, specifically, are nested under a Filings2014 key. The following three lines of code show, respectively, the top-level 'keys' for the data, the number of objects (filings) listed under that major key, and the first index filing. We see there are 387,529  filings in the 2014 index file.

# %%
print('Top-level key(s) in the 2014 index file:', data.keys(), '\n')
print('# of filings in the 2014 index file:', len(data['Filings2014']), '\n')
data['Filings2014'][0] # Checking the first row in index file
# Out:
# Top-level key(s) in the 2014 index file: dict_keys(['Filings2014'])
#
# # of filings in the 2014 index file: 387529
# {'EIN': '760740805',
#  'TaxPeriod': '201406',
#  'DLN': '93492311012114',
#  'FormType': '990EZ',
#  'URL': 'https://s3.amazonaws.com/irs-form-990/201413119349201211_public.xml',
#  'OrganizationName': 'ROYAL HIGH BAND BOOSTERS',
#  'SubmittedOn': '2014-12-08',
#  'ObjectId': '201413119349201211',
#  'LastUpdated': '2016-03-21T17:23:53'}

# %% [markdown]
# ### Collect all XML files

# %% [markdown]
# The next part will be collecting all XML files for a specific year and storing those files in your local machine. I suggest creating different folders for different years to store these XML files because the following code will go to specific folder to convert these XML files to csv.
#
# **Notice**: This process will take a long time to run so you should expect to run your computer for the entire 36 to 48 hours. You shouldn't let the computer sleep or shut down because it will terminate the connection to AWS server and hence, the process will stop.

# %%
import time
for item in data['Filings2014']:
    # url of rss feed
    url = item['URL']
    xmlName = url.replace('https://s3.amazonaws.com/irs-form-990/','')
    # creating HTTP response object from given url
    resp = ''
    while resp == '':
        try:
            resp = requests.get(url)
            break
        except:
            time.sleep(10)
    # saving the xml file to your local machine
    with open('C:\\Users\\hangl\\Documents\\Summer RA\\Non-profit\\IRS\\XML_2014\\'+xmlName, 'wb') as f:
        f.write(resp.content)

# %% [markdown]
# ### Looping through all XML files to convert to csv

# %% [markdown]
# #### Creating different functions

# %% [markdown]
# For this step, I will create different function to collect information stored in XML files.
#
# 1. The first function ***getIRS900Info*** will specify the node to find information in ReturnHeader and ReturnData part of XML files.
#
# 2. The second function ***getChildNodeForReturnHeader*** will check if there is any infomation under ReturnHeader section in the SML file. If yes, it will get the data and store in python dictionary.
#
# 2. The third function ***getChildNodeForReturnData*** will check if there is any infomation under ReturnData section in the XML file. If yes, it will get the data and store in python dictionary.

# %%
def getIRS990Info(xmlFileName,dictData,schedule):
    tree = etree.parse(xmlFileName)
    root = tree.getroot()
    # get data from ReturnHeader
    pNode = root.find('name:ReturnHeader',sitename)
    getChildNodeForReturnHeader(pNode,dictData)
    # get data from ReturnData
    pNode = root.find('name:ReturnData/name:'+schedule,sitename)
    getChildNodeForReturnData(pNode,dictData,schedule)

# %%
def getChildNodeForReturnHeader(node,dictdata):
    if node == None:
        return
    #if node has not children, add node to dictionary
    if len(node.getchildren()) == 0 :
        tag = node.tag.replace(siteaddress,'')
        text = ''
        if node.text != None :
            text = str(node.text.encode('utf8')).replace('b','').replace("'","")
        dictdata.update({tag : text})
        return
    #if node has children continue find child node
    else:
        for child in node:
            getChildNodeForReturnHeader(child,dictdata)

# %%
def getChildNodeForReturnData(node,dictdata,schedualName):  
    if node == None:
        return
    #if node has not children, add node to dictionary
    if len(node.getchildren()) == 0 :
        tag = schedualName
        text = ''
        if node.text != None :
            text = str(node.text.encode('utf8')).replace('b','').replace("'","")
        dictdata.update({tag : text})
        return
    #if node has children, continue find child node
    else:
        for child in node:
            getChildNodeForReturnData(child,dictdata,schedualName+'-'+child.tag.replace(siteaddress,''))

# %% [markdown]
# #### Getting the content of data

# %% [markdown]
# For data management purposes, we will collect different parts of data and store in different files. In this part, you have to modify which parts of the data you want to collect. For example, IRS990, Schedule D, Schedule C, etc.
#
# To collect different parts, you have to modify **scheduleValue** in the following code.  Keys to replace:
#
# | Part | Keywords|
# | ----------- | ----------- |
# | All IRS990 |IRS990 |
# | Schedule A |IRS990ScheduleA |
# | Schedule B |IRS990ScheduleB |
# | Schedule C |IRS990ScheduleC |
# | Schedule D| IRS990ScheduleD |
# | Schedule H |IRS990ScheduleH |
# | Schedule J | IRS990ScheduleJ |

# %%
# State you want to collect 990 or Schedule data 
#In case you want to collect data for Schedule D, this will be used: scheduleValue = 'IRS990ScheduleD' 
scheduleValue = 'IRS990' # Getting IRS990 data

# %% [markdown]
# Next, in brief, what we want to do is write code that will loop over all XML files stored in our local folder, grab those data, convert them to a dictionary, and then store them into a new csv file with which each corporation will be stored in a row and the associated data will be stored in a column.
#
# Because all information will be stored in different columns, you will expect > 600 columns for IRS 990, > 200 columns for SheduleD and for other schedules. You should expect the code to run from 15 to 30 mins for this step.

# %%
# create empty list for news items 
siteaddress = '{http://www.irs.gov/efile}'
sitename = {'name':'http://www.irs.gov/efile'}
directory = 'C:\\Users\\hangl\\Documents\\Summer RA\\Non-profit\\IRS\\XML_2014\\' # You need to modify the folder for specific year
dictItems = []
entries = os.listdir(directory)
for entry in entries:
    dictData = {}
    getIRS990Info(directory+entry,dictData,scheduleValue)
    if len(dictData) > 0 :
        dictItems.append(dictData)

# %% [markdown]
# Next, we have to conver Python dictionary to normal data frame with rows and columns.

# %%
df_990 = pd.DataFrame(dictItems) # Turning dictinary into pandas data frame for ScheduleD
#df_990 = pd.DataFrame(dictItems[0:150000]) # Collect the first part of data for IRS 900. You can just get rid of the # symbol to run the code
#df_990 = pd.DataFrame(dictItems[150000:387527]) # Collect the second part, You can just get rid of the # symbol to run the code

# %% [markdown]
# ***Note***: Usually, for ScheduleD, you can convert all information stored in dictionary into data frame in python. However, for IRS 990, the amount of data is huge so it will take a very long time to convert all data into only one file. What I suggest to do is seperating them into 2 or 3 different files and then store them as seperate csv files.
#
# You can modify the code to convert a part of data for IRS990 using the Ptyhon index. For example, there are 387,526 fillings for 2014 (the numbers of fillings in the index indicates 387,529 fillings but there are 3 duplicates so the final number is 387,526 fillings), we should expect the index run from 0 to 387,527. You can modify to code to convert data into 2 files: from index 0  to 150,000 and from index 150,000 - 387,527.
#
# I named the data frame with the same name so you don't get confused when creating too much dataframe.

# %% [markdown]
# #### Checking data

# %% [markdown]
# To make sure we collect all data correctly, let's check the data dimensions using shape function in Python. The first value is the number of rows and the second value is the number of columns.
#
# For example, the second part of IRS 900 - 2014 has 237,526 rows and 1251 columns.

# %%
df_990.shape
# Out:
# (237526, 1251)

# %% [markdown]
# You can also check the missing values in each columns in the data frame using this code

# %%
df_990.isnull().sum()
# Out:
# ReturnTs                                                                                   0
# TaxPeriodEndDt                                                                             0
# PreparerFirmEIN                                                                        38036
# BusinessNameLine1Txt                                                                       0
# AddressLine1Txt                                                                            0
# CityNm                                                                                     0
# StateAbbreviationCd                                                                       23
# ZIPCd                                                                                     23
# ReturnTypeCd                                                                               0
# TaxPeriodBeginDt                                                                           0
# EIN                                                                                        0
# BusinessNameControlTxt                                                                     0
# PhoneNum                                                                                  91
# PersonNm                                                                                   0
# PersonTitleTxt                                                                             0
# SignatureDt                                                                                0
# DiscussWithPaidPreparerInd                                                             12440
# PreparerPersonNm                                                                        4856
# PTIN                                                                                   15603
# IPv4AddressTxt                                                                         38541
# IPDt                                                                                   46022
# IPTm                                                                                   46187
# IPTimezoneCd                                                                           53076
# FilingLicenseTypeCd                                                                    40665
# AtSubmissionCreationDeviceId                                                           21176
# AtSubmissionFilingDeviceId                                                             21176
# TaxYr                                                                                      0
# BuildTS                                                                                    0
# PreparationDt                                                                          44486
# SelfEmployedInd                                                                        82878
# FederalOriginalSubmissionId                                                            87799
# FederalOriginalSubmissionIdDt                                                          88016
# BusinessNameLine2Txt                                                                   76973
# InCareOfNm                                                                             95444
# IRS990-PrincipalOfcrBusinessName-BusinessNameLine1Txt                                  98928
# IRS990-USAddress-AddressLine1Txt                                                       52842
# IRS990-USAddress-CityNm                                                                52842
# IRS990-USAddress-StateAbbreviationCd                                                   52842
# IRS990-USAddress-ZIPCd                                                                 52842
# IRS990-GrossReceiptsAmt                                                                41613
# IRS990-GroupReturnForAffiliatesInd                                                     41613
# IRS990-Organization501c3Ind                                                            55713
# IRS990-WebsiteAddressTxt                                                               47131
# IRS990-TypeOfOrganizationCorpInd                                                       48314
# IRS990-ActivityOrMissionDesc                                                           41613
# IRS990-VotingMembersGoverningBodyCnt                                                   41613
# IRS990-VotingMembersIndependentCnt                                                     41613
# IRS990-TotalEmployeeCnt                                                                41613
# IRS990-TotalVolunteersCnt                                                              56568
# IRS990-TotalGrossUBIAmt                                                                41613
# IRS990-NetUnrelatedBusTxblIncmAmt                                                      70037
# IRS990-PYContributionsGrantsAmt                                                        48912
# IRS990-CYContributionsGrantsAmt                                                        41613
# IRS990-PYProgramServiceRevenueAmt                                                      53634
# IRS990-CYProgramServiceRevenueAmt                                                      41613
# IRS990-PYInvestmentIncomeAmt                                                           51485
# IRS990-CYInvestmentIncomeAmt                                                           41613
# IRS990-PYOtherRevenueAmt                                                               55743
# IRS990-CYOtherRevenueAmt                                                               41613
# IRS990-PYTotalRevenueAmt                                                               43268
# IRS990-CYTotalRevenueAmt                                                               41613
# IRS990-PYGrantsAndSimilarPaidAmt                                                       66042
# IRS990-CYGrantsAndSimilarPaidAmt                                                       41613
# IRS990-CYBenefitsPaidToMembersAmt                                                      41613
# IRS990-PYSalariesCompEmpBnftPaidAmt                                                    52508
# IRS990-CYSalariesCompEmpBnftPaidAmt                                                    41613
# IRS990-CYTotalProfFndrsngExpnsAmt                                                      41613
# IRS990-CYTotalFundraisingExpenseAmt                                                    41613
# IRS990-PYOtherExpensesAmt                                                              43469
# IRS990-CYOtherExpensesAmt                                                              41613
# IRS990-PYTotalExpensesAmt                                                              43344
# IRS990-CYTotalExpensesAmt                                                              41613
# IRS990-PYRevenuesLessExpensesAmt                                                       43304
# IRS990-CYRevenuesLessExpensesAmt                                                       41613
# IRS990-TotalAssetsBOYAmt                                                               42322
# IRS990-TotalAssetsEOYAmt                                                               41613
# IRS990-TotalLiabilitiesBOYAmt                                                          50200
# IRS990-TotalLiabilitiesEOYAmt                                                          41613
# IRS990-NetAssetsOrFundBalancesBOYAmt                                                   42367
# IRS990-NetAssetsOrFundBalancesEOYAmt                                                   41613
# IRS990-MissionDesc                                                                     41672
# IRS990-SignificantNewProgramSrvcInd                                                    42064
# IRS990-SignificantChangeInd                                                            42077
# IRS990-ExpenseAmt                                                                      50807
# IRS990-Desc                                                                            41613
# IRS990-TotalProgramServiceExpensesAmt                                                  49835
# IRS990-DescribedInSection501c3Ind                                                      41613
# IRS990-ScheduleBRequiredInd                                                            41613
# IRS990-PoliticalCampaignActyInd                                                        41613
# IRS990-LobbyingActivitiesInd                                                           52665
# IRS990-SubjectToProxyTaxInd                                                            43100
# IRS990-DonorAdvisedFundInd                                                             41613
# IRS990-ConservationEasementsInd                                                        41613
# IRS990-CollectionsOfArtInd                                                             41613
# IRS990-CreditCounselingInd                                                             41613
# IRS990-TempOrPermanentEndowmentsInd                                                    41613
# IRS990-ReportLandBuildingEquipmentInd                                                  41613
# IRS990-ReportInvestmentsOtherSecInd                                                    41613
# IRS990-ReportProgramRelatedInvstInd                                                    41613
# IRS990-ReportOtherAssetsInd                                                            41613
# IRS990-ReportOtherLiabilitiesInd                                                       41613
# IRS990-IncludeFIN48FootnoteInd                                                         41613
# IRS990-IndependentAuditFinclStmtInd                                                    41613
# IRS990-ConsolidatedAuditFinclStmtInd                                                   41613
# IRS990-SchoolOperatingInd                                                              41613
# IRS990-ForeignOfficeInd                                                                41613
# IRS990-ForeignActivitiesInd                                                            41613
# IRS990-MoreThan5000KToOrgInd                                                           41613
# IRS990-MoreThan5000KToIndividualsInd                                                   41613
# IRS990-ProfessionalFundraisingInd                                                      41613
# IRS990-FundraisingActivitiesInd                                                        41613
# IRS990-GamingActivitiesInd                                                             41613
# IRS990-OperateHospitalInd                                                              41613
# IRS990-GrantsToOrganizationsInd                                                        41613
# IRS990-GrantsToIndividualsInd                                                          41613
# IRS990-ScheduleJRequiredInd                                                            41613
# IRS990-TaxExemptBondsInd                                                               41613
# IRS990-EngagedInExcessBenefitTransInd                                                  50900
# IRS990-PYExcessBenefitTransInd                                                         50902
# IRS990-LoanOutstandingInd                                                              41613
# IRS990-GrantToRelatedPersonInd                                                         41613
# IRS990-BusinessRlnWithOrgMemInd                                                        41613
# IRS990-BusinessRlnWithFamMemInd                                                        41613
# IRS990-BusinessRlnWithOfficerEntInd                                                    41613
# IRS990-DeductibleNonCashContriInd                                                      41613
# IRS990-DeductibleArtContributionInd                                                    41613
# IRS990-TerminateOperationsInd                                                          41613
# IRS990-PartialLiquidationInd                                                           41613
# IRS990-DisregardedEntityInd                                                            41613
# IRS990-RelatedEntityInd                                                                41613
# IRS990-RelatedOrganizationCtrlEntInd                                                   41613
# IRS990-TrnsfrExmptNonChrtblRltdOrgInd                                                  56904
# IRS990-ActivitiesConductedPrtshpInd                                                    41613
# IRS990-ScheduleORequiredInd                                                            41613
# IRS990-IRPDocumentCnt                                                                  41613
# IRS990-IRPDocumentW2GCnt                                                               41613
# IRS990-EmployeeCnt                                                                     41613
# IRS990-EmploymentTaxReturnsFiledInd                                                    59373
# IRS990-UnrelatedBusIncmOverLimitInd                                                    41613
# IRS990-ForeignFinancialAccountInd                                                      41613
# IRS990-ProhibitedTaxShelterTransInd                                                    41613
# IRS990-TaxablePartyNotificationInd                                                     41613
# IRS990-NondeductibleContributionsInd                                                   41613
# IRS990-QuidProQuoContributionsInd                                                      58523
# IRS990-RcvFndsToPayPrsnlBnftCntrctInd                                                  65617
# IRS990-PayPremiumsPrsnlBnftCntrctInd                                                   65604
# IRS990-Form8899Filedind                                                                86220
# IRS990-Form1098CFiledInd                                                               86154
# IRS990-IndoorTanningServicesInd                                                        41613
# IRS990-InfoInScheduleOPartVIInd                                                        43250
# IRS990-GoverningBodyVotingMembersCnt                                                   41613
# IRS990-IndependentVotingMemberCnt                                                      41613
# IRS990-FamilyOrBusinessRlnInd                                                          41613
# IRS990-DelegationOfMgmtDutiesInd                                                       41613
# IRS990-ChangeToOrgDocumentsInd                                                         41613
# IRS990-MaterialDiversionOrMisuseInd                                                    41613
# IRS990-MembersOrStockholdersInd                                                        41613
# IRS990-ElectionOfBoardMembersInd                                                       41613
# IRS990-DecisionsSubjectToApprovaInd                                                    41613
# IRS990-MinutesOfGoverningBodyInd                                                       41613
# IRS990-MinutesOfCommitteesInd                                                          41769
# IRS990-OfficerMailingAddressInd                                                        41613
# IRS990-LocalChaptersInd                                                                41613
# IRS990-Form990ProvidedToGvrnBodyInd                                                    41613
# IRS990-ConflictOfInterestPolicyInd                                                     41613
# IRS990-AnnualDisclosureCoveredPrsnInd                                                  58844
# IRS990-RegularMonitoringEnfrcInd                                                       58846
# IRS990-WhistleblowerPolicyInd                                                          41613
# IRS990-DocumentRetentionPolicyInd                                                      41613
# IRS990-CompensationProcessCEOInd                                                       41881
# IRS990-CompensationProcessOtherInd                                                     41909
# IRS990-InvestmentInJointVentureInd                                                     41613
# IRS990-StatesWhereCopyOfReturnIsFldCd                                                  69538
# IRS990-UponRequestInd                                                                  46534
# IRS990-BooksInCareOfDetail-BusinessName-BusinessNameLine1Txt                           76285
# IRS990-BooksInCareOfDetail-PhoneNum                                                    41613
# IRS990-BooksInCareOfDetail-USAddress-AddressLine1Txt                                   41733
# IRS990-BooksInCareOfDetail-USAddress-CityNm                                            41733
# IRS990-BooksInCareOfDetail-USAddress-StateAbbreviationCd                               41733
# IRS990-BooksInCareOfDetail-USAddress-ZIPCd                                             41733
# IRS990-NoListedPersonsCompensatedInd                                                   74531
# IRS990-Form990PartVIISectionAGrp-BusinessName-BusinessNameLine1Txt                     99092
# IRS990-Form990PartVIISectionAGrp-TitleTxt                                              41613
# IRS990-Form990PartVIISectionAGrp-IndividualTrusteeOrDirectorInd                        47437
# IRS990-Form990PartVIISectionAGrp-OfficerInd                                            46257
# IRS990-Form990PartVIISectionAGrp-ReportableCompFromOrgAmt                              42015
# IRS990-Form990PartVIISectionAGrp-ReportableCompFromRltdOrgAmt                          42057
# IRS990-Form990PartVIISectionAGrp-OtherCompensationAmt                                  42059
# IRS990-TotalReportableCompFromOrgAmt                                                   56641
# IRS990-TotReportableCompRltdOrgAmt                                                     68137
# IRS990-TotalOtherCompensationAmt                                                       65120
# IRS990-IndivRcvdGreaterThan100KCnt                                                     58407
# IRS990-FormerOfcrEmployeesListedInd                                                    41613
# IRS990-TotalCompGreaterThan150KInd                                                     41613
# IRS990-CompensationFromOtherSrcsInd                                                    41613
# IRS990-CntrctRcvdGreaterThan100KCnt                                                    63083
# IRS990-InfoInScheduleOPartVIIIInd                                                      99323
# IRS990-FederatedCampaignsAmt                                                           96587
# IRS990-MembershipDuesAmt                                                               89973
# IRS990-FundraisingAmt                                                                  90115
# IRS990-RelatedOrganizationsAmt                                                         96400
# IRS990-GovernmentGrantsAmt                                                             85102
# IRS990-AllOtherContributionsAmt                                                        60793
# IRS990-TotalContributionsAmt                                                           51191
# IRS990-ProgramServiceRevenueGrp-Desc                                                   61033
# IRS990-ProgramServiceRevenueGrp-TotalRevenueColumnAmt                                  61019
# IRS990-ProgramServiceRevenueGrp-RelatedOrExemptFuncIncomeAmt                           64861
# IRS990-TotalOthProgramServiceRevGrp-TotalRevenueColumnAmt                              95657
# IRS990-TotalOthProgramServiceRevGrp-RelatedOrExemptFuncIncomeAmt                       96339
# IRS990-TotalOthProgramServiceRevGrp-UnrelatedBusinessRevenueAmt                        98811
# IRS990-TotalOthProgramServiceRevGrp-ExclusionAmt                                       98918
# IRS990-TotalProgramServiceRevenueAmt                                                   56512
# IRS990-InvestmentIncomeGrp-TotalRevenueColumnAmt                                       53756
# IRS990-InvestmentIncomeGrp-ExclusionAmt                                                70273
# IRS990-GrossRentsGrp-RealAmt                                                           92143
# IRS990-RentalIncomeOrLossGrp-RealAmt                                                   89200
# IRS990-RentalIncomeOrLossGrp-PersonalAmt                                               95832
# IRS990-NetRentalIncomeOrLossGrp-TotalRevenueColumnAmt                                  81869
# IRS990-NetRentalIncomeOrLossGrp-RelatedOrExemptFuncIncomeAmt                           96904
# IRS990-NetRentalIncomeOrLossGrp-ExclusionAmt                                           95569
# IRS990-GrossAmountSalesAssetsGrp-SecuritiesAmt                                         89076
# IRS990-LessCostOthBasisSalesExpnssGrp-SecuritiesAmt                                    89269
# IRS990-GainOrLossGrp-SecuritiesAmt                                                     88059
# IRS990-GainOrLossGrp-OtherAmt                                                          92582
# IRS990-NetGainOrLossInvestmentsGrp-TotalRevenueColumnAmt                               76053
# IRS990-NetGainOrLossInvestmentsGrp-ExclusionAmt                                        90426
# IRS990-GrossSalesOfInventoryAmt                                                        90183
# IRS990-NetIncomeOrLossGrp-TotalRevenueColumnAmt                                        82327
# IRS990-NetIncomeOrLossGrp-RelatedOrExemptFuncIncomeAmt                                 94760
# IRS990-OtherRevenueMiscGrp-Desc                                                        78819
# IRS990-OtherRevenueMiscGrp-BusinessCd                                                  84420
# IRS990-OtherRevenueMiscGrp-TotalRevenueColumnAmt                                       78973
# IRS990-OtherRevenueMiscGrp-RelatedOrExemptFuncIncomeAmt                                85452
# IRS990-MiscellaneousRevenueGrp-TotalRevenueColumnAmt                                   97151
# IRS990-MiscellaneousRevenueGrp-RelatedOrExemptFuncIncomeAmt                            97904
# IRS990-MiscellaneousRevenueGrp-UnrelatedBusinessRevenueAmt                             99150
# IRS990-MiscellaneousRevenueGrp-ExclusionAmt                                            98706
# IRS990-OtherRevenueTotalAmt                                                            70046
# IRS990-TotalRevenueGrp-TotalRevenueColumnAmt                                           41613
# IRS990-TotalRevenueGrp-RelatedOrExemptFuncIncomeAmt                                    48153
# IRS990-TotalRevenueGrp-UnrelatedBusinessRevenueAmt                                     68983
# IRS990-TotalRevenueGrp-ExclusionAmt                                                    55892
# IRS990-ForeignGrantsGrp-TotalAmt                                                       84446
# IRS990-ForeignGrantsGrp-ProgramServicesAmt                                             97354
# IRS990-OtherSalariesAndWagesGrp-TotalAmt                                               58546
# IRS990-OtherSalariesAndWagesGrp-ProgramServicesAmt                                     70271
# IRS990-OtherSalariesAndWagesGrp-ManagementAndGeneralAmt                                75693
# IRS990-PensionPlanContributionsGrp-TotalAmt                                            75826
# IRS990-PensionPlanContributionsGrp-ProgramServicesAmt                                  89870
# IRS990-PensionPlanContributionsGrp-ManagementAndGeneralAmt                             90794
# IRS990-OtherEmployeeBenefitsGrp-TotalAmt                                               66920
# IRS990-OtherEmployeeBenefitsGrp-ProgramServicesAmt                                     79652
# IRS990-OtherEmployeeBenefitsGrp-ManagementAndGeneralAmt                                82170
# IRS990-PayrollTaxesGrp-TotalAmt                                                        58757
# IRS990-PayrollTaxesGrp-ProgramServicesAmt                                              70777
# IRS990-PayrollTaxesGrp-ManagementAndGeneralAmt                                         74735
# IRS990-FeesForServicesAccountingGrp-TotalAmt                                           52364
# IRS990-FeesForServicesAccountingGrp-ProgramServicesAmt                                 85873
# IRS990-FeesForServicesAccountingGrp-ManagementAndGeneralAmt                            66322
# IRS990-FeesForSrvcInvstMgmntFeesGrp-TotalAmt                                           80098
# IRS990-FeesForSrvcInvstMgmntFeesGrp-ManagementAndGeneralAmt                            94085
# IRS990-FeesForServicesOtherGrp-TotalAmt                                                64772
# IRS990-FeesForServicesOtherGrp-ProgramServicesAmt                                      80280
# IRS990-FeesForServicesOtherGrp-ManagementAndGeneralAmt                                 82491
# IRS990-FeesForServicesOtherGrp-FundraisingAmt                                          92634
# IRS990-AdvertisingGrp-TotalAmt                                                         63846
# IRS990-AdvertisingGrp-ProgramServicesAmt                                               79928
# IRS990-OfficeExpensesGrp-TotalAmt                                                      50741
# IRS990-OfficeExpensesGrp-ManagementAndGeneralAmt                                       66887
# IRS990-OccupancyGrp-TotalAmt                                                           57872
# IRS990-OccupancyGrp-ProgramServicesAmt                                                 71757
# IRS990-TravelGrp-TotalAmt                                                              62817
# IRS990-TravelGrp-ProgramServicesAmt                                                    76554
# IRS990-TravelGrp-ManagementAndGeneralAmt                                               81996
# IRS990-ConferencesMeetingsGrp-TotalAmt                                                 67550
# IRS990-ConferencesMeetingsGrp-ManagementAndGeneralAmt                                  87419
# IRS990-InterestGrp-TotalAmt                                                            73527
# IRS990-InterestGrp-ProgramServicesAmt                                                  89527
# IRS990-PaymentsToAffiliatesGrp-TotalAmt                                                84159
# IRS990-PaymentsToAffiliatesGrp-ProgramServicesAmt                                      98183
# IRS990-PaymentsToAffiliatesGrp-ManagementAndGeneralAmt                                 98768
# IRS990-PaymentsToAffiliatesGrp-FundraisingAmt                                          99208
# IRS990-DepreciationDepletionGrp-TotalAmt                                               57281
# IRS990-DepreciationDepletionGrp-ProgramServicesAmt                                     72424
# IRS990-InsuranceGrp-TotalAmt                                                           54184
# IRS990-InsuranceGrp-ProgramServicesAmt                                                 72370
# IRS990-OtherExpensesGrp-Desc                                                           45928
# IRS990-OtherExpensesGrp-TotalAmt                                                       45752
# IRS990-OtherExpensesGrp-ProgramServicesAmt                                             56118
# IRS990-OtherExpensesGrp-ManagementAndGeneralAmt                                        67400
# IRS990-AllOtherExpensesGrp-TotalAmt                                                    60656
# IRS990-AllOtherExpensesGrp-ProgramServicesAmt                                          71381
# IRS990-AllOtherExpensesGrp-ManagementAndGeneralAmt                                     75341
# IRS990-AllOtherExpensesGrp-FundraisingAmt                                              89425
# IRS990-TotalFunctionalExpensesGrp-TotalAmt                                             41613
# IRS990-TotalFunctionalExpensesGrp-ProgramServicesAmt                                   46192
# IRS990-TotalFunctionalExpensesGrp-ManagementAndGeneralAmt                              46408
# IRS990-TotalFunctionalExpensesGrp-FundraisingAmt                                       46787
# IRS990-CashNonInterestBearingGrp-BOYAmt                                                47657
# IRS990-CashNonInterestBearingGrp-EOYAmt                                                46428
# IRS990-SavingsAndTempCashInvstGrp-BOYAmt                                               67118
# IRS990-SavingsAndTempCashInvstGrp-EOYAmt                                               62697
# IRS990-AccountsReceivableGrp-BOYAmt                                                    73037
# IRS990-AccountsReceivableGrp-EOYAmt                                                    67183
# IRS990-ReceivablesFromOfficersEtcGrp-BOYAmt                                            96103
# IRS990-ReceivablesFromOfficersEtcGrp-EOYAmt                                            87161
# IRS990-RcvblFromDisqualifiedPrsnGrp-EOYAmt                                             87591
# IRS990-PrepaidExpensesDefrdChargesGrp-BOYAmt                                           73852
# IRS990-PrepaidExpensesDefrdChargesGrp-EOYAmt                                           67951
# IRS990-LandBldgEquipCostOrOtherBssAmt                                                  57683
# IRS990-LandBldgEquipAccumDeprecAmt                                                     59273
# IRS990-LandBldgEquipBasisNetGrp-BOYAmt                                                 58350
# IRS990-LandBldgEquipBasisNetGrp-EOYAmt                                                 55545
# IRS990-InvestmentsPubTradedSecGrp-BOYAmt                                               84158
# IRS990-InvestmentsPubTradedSecGrp-EOYAmt                                               76788
# IRS990-InvestmentsOtherSecuritiesGrp-BOYAmt                                            91597
# IRS990-InvestmentsProgramRelatedGrp-BOYAmt                                             95114
# IRS990-OtherAssetsTotalGrp-BOYAmt                                                      76177
# IRS990-OtherAssetsTotalGrp-EOYAmt                                                      70586
# IRS990-TotalAssetsGrp-BOYAmt                                                           41613
# IRS990-TotalAssetsGrp-EOYAmt                                                           41613
# IRS990-AccountsPayableAccrExpnssGrp-BOYAmt                                             61266
# IRS990-AccountsPayableAccrExpnssGrp-EOYAmt                                             60742
# IRS990-DeferredRevenueGrp-BOYAmt                                                       84649
# IRS990-DeferredRevenueGrp-EOYAmt                                                       84301
# IRS990-TaxExemptBondLiabilitiesGrp-BOYAmt                                              95872
# IRS990-TaxExemptBondLiabilitiesGrp-EOYAmt                                              95927
# IRS990-MortgNotesPyblScrdInvstPropGrp-BOYAmt                                           86086
# IRS990-MortgNotesPyblScrdInvstPropGrp-EOYAmt                                           86041
# IRS990-UnsecuredNotesLoansPayableGrp-BOYAmt                                            93914
# IRS990-UnsecuredNotesLoansPayableGrp-EOYAmt                                            93893
# IRS990-OtherLiabilitiesGrp-BOYAmt                                                      75948
# IRS990-OtherLiabilitiesGrp-EOYAmt                                                      75928
# IRS990-TotalLiabilitiesGrp-BOYAmt                                                      41613
# IRS990-TotalLiabilitiesGrp-EOYAmt                                                      41613
# IRS990-UnrestrictedNetAssetsGrp-BOYAmt                                                 56045
# IRS990-UnrestrictedNetAssetsGrp-EOYAmt                                                 55739
# IRS990-TemporarilyRstrNetAssetsGrp-BOYAmt                                              81732
# IRS990-TemporarilyRstrNetAssetsGrp-EOYAmt                                              81259
# IRS990-PermanentlyRstrNetAssetsGrp-BOYAmt                                              91467
# IRS990-PermanentlyRstrNetAssetsGrp-EOYAmt                                              91366
# IRS990-TotalNetAssetsFundBalanceGrp-BOYAmt                                             41613
# IRS990-TotalNetAssetsFundBalanceGrp-EOYAmt                                             41613
# IRS990-TotLiabNetAssetsFundBalanceGrp-BOYAmt                                           41613
# IRS990-TotLiabNetAssetsFundBalanceGrp-EOYAmt                                           41613
# IRS990-ReconcilationRevenueExpnssAmt                                                   41613
# IRS990-NetUnrlzdGainsLossesInvstAmt                                                    85261
# IRS990-OtherChangesInNetAssetsAmt                                                      67738
# IRS990-MethodOfAccountingAccrualInd                                                    61283
# IRS990-AccountantCompileOrReviewInd                                                    41613
# IRS990-FSAuditedInd                                                                    41613
# IRS990-FSAuditedBasisGrp-SeparateBasisFinclStmtInd                                     82141
# IRS990-AuditCommitteeInd                                                               68058
# IRS990-FederalGrantAuditRequiredInd                                                    47226
# IRS990-DoingBusinessAsName-BusinessNameLine1Txt                                        96479
# IRS990-PrincipalOfficerNm                                                              49656
# IRS990-Organization501cInd                                                             85929
# IRS990-LegalDomicileStateCd                                                            44440
# IRS990-InfoInScheduleOPartIIIInd                                                       80707
# IRS990-BackupWthldComplianceInd                                                        63923
# IRS990-BooksInCareOfDetail-PersonNm                                                    65328
# IRS990-Form990PartVIISectionAGrp-PersonNm                                              42085
# IRS990-InvestmentIncomeGrp-RelatedOrExemptFuncIncomeAmt                                88643
# IRS990-GamingGrossIncomeAmt                                                            94985
# IRS990-GamingDirectExpensesAmt                                                         95131
# IRS990-NetIncomeFromGamingGrp-TotalRevenueColumnAmt                                    86292
# IRS990-NetIncomeFromGamingGrp-RelatedOrExemptFuncIncomeAmt                             98820
# IRS990-FeesForServicesLegalGrp-TotalAmt                                                71345
# IRS990-FeesForServicesLegalGrp-ManagementAndGeneralAmt                                 87028
# IRS990-AdvertisingGrp-FundraisingAmt                                                   91440
# IRS990-OfficeExpensesGrp-ProgramServicesAmt                                            70415
# IRS990-OfficeExpensesGrp-FundraisingAmt                                                87093
# IRS990-OccupancyGrp-FundraisingAmt                                                     90900
# IRS990-OrganizationFollowsSFAS117Ind                                                   55178
# IRS990-MethodOfAccountingCashInd                                                       81598
# IRS990-FormationYr                                                                     45570
# IRS990-RevenueAmt                                                                      70520
# IRS990-QuidProQuoContriDisclInd                                                        94553
# IRS990-Form8282PropertyDisposedOfInd                                                   58595
# IRS990-DAFExcessBusinessHoldingsInd                                                    86451
# IRS990-TaxableDistributionsInd                                                         86632
# IRS990-DistributionToDonorInd                                                          86683
# IRS990-Form990PartVIISectionAGrp-AverageHoursPerWeekRt                                 44727
# IRS990-ProgramServiceRevenueGrp-BusinessCd                                             70830
# IRS990-GrantsToDomesticOrgsGrp-TotalAmt                                                76946
# IRS990-GrantsToDomesticIndividualsGrp-TotalAmt                                         80092
# IRS990-BenefitsToMembersGrp-TotalAmt                                                   84096
# IRS990-CompCurrentOfcrDirectorsGrp-TotalAmt                                            65790
# IRS990-CompCurrentOfcrDirectorsGrp-ManagementAndGeneralAmt                             79564
# IRS990-CompDisqualPersonsGrp-TotalAmt                                                  84781
# IRS990-FeesForServicesManagementGrp-TotalAmt                                           79564
# IRS990-FeesForServicesLobbyingGrp-TotalAmt                                             84543
# IRS990-FeesForServicesProfFundraising                                                  98173
# IRS990-InformationTechnologyGrp-TotalAmt                                               72716
# IRS990-RoyaltiesGrp-TotalAmt                                                           85619
# IRS990-PymtTravelEntrtnmntPubOfclGrp-TotalAmt                                          85840
# IRS990-OrgDoesNotFollowSFAS117Ind                                                      86574
# IRS990-RtnEarnEndowmentIncmOthFndsGrp-BOYAmt                                           87249
# IRS990-RtnEarnEndowmentIncmOthFndsGrp-EOYAmt                                           87180
# IRS990-AcctCompileOrReviewBasisGrp-SeparateBasisFinclStmtInd                           94332
# IRS990-AmendedReturnInd                                                                99453
# IRS990-PYBenefitsPaidToMembersAmt                                                      72413
# IRS990-PYTotalProfFndrsngExpnsAmt                                                      72763
# IRS990-ProgSrvcAccomActy2Grp-ExpenseAmt                                                84966
# IRS990-ProgSrvcAccomActy2Grp-GrantAmt                                                  96096
# IRS990-ProgSrvcAccomActy2Grp-RevenueAmt                                                92076
# IRS990-ProgSrvcAccomActy2Grp-Desc                                                      82055
# IRS990-ProgSrvcAccomActy3Grp-ExpenseAmt                                                89598
# IRS990-ProgSrvcAccomActy3Grp-RevenueAmt                                                94737
# IRS990-ProgSrvcAccomActy3Grp-Desc                                                      87449
# IRS990-Form990PartVIISectionAGrp-AverageHoursPerWeekRltdOrgRt                          77265
# IRS990-OtherRevenueMiscGrp-ExclusionAmt                                                93569
# IRS990-GrantsToDomesticOrgsGrp-ProgramServicesAmt                                      88930
# IRS990-CompCurrentOfcrDirectorsGrp-ProgramServicesAmt                                  80443
# IRS990-CompCurrentOfcrDirectorsGrp-FundraisingAmt                                      89252
# IRS990-OtherSalariesAndWagesGrp-FundraisingAmt                                         87377
# IRS990-OtherEmployeeBenefitsGrp-FundraisingAmt                                         90664
# IRS990-FeesForServicesLegalGrp-ProgramServicesAmt                                      92463
# IRS990-FeesForServicesLobbyingGrp-ManagementAndGeneralAmt                              98807
# IRS990-OccupancyGrp-ManagementAndGeneralAmt                                            77397
# IRS990-ConferencesMeetingsGrp-ProgramServicesAmt                                       83789
# IRS990-DepreciationDepletionGrp-ManagementAndGeneralAmt                                79633
# IRS990-InsuranceGrp-ManagementAndGeneralAmt                                            72779
# IRS990-InsuranceGrp-FundraisingAmt                                                     91858
# IRS990-OtherExpensesGrp-FundraisingAmt                                                 84870
# IRS990-PledgesAndGrantsReceivableGrp-BOYAmt                                            87286
# IRS990-PledgesAndGrantsReceivableGrp-EOYAmt                                            79395
# IRS990-OthNotesLoansReceivableNetGrp-BOYAmt                                            92884
# IRS990-OthNotesLoansReceivableNetGrp-EOYAmt                                            84322
# IRS990-InvestmentsOtherSecuritiesGrp-EOYAmt                                            83097
# IRS990-LoansFromOfficersDirectorsGrp-BOYAmt                                            95374
# IRS990-LoansFromOfficersDirectorsGrp-EOYAmt                                            95430
# IRS990-InfoInScheduleOPartXIInd                                                        92101
# IRS990-FSAuditedBasisGrp-ConsolidatedBasisFinclStmtInd                                 93598
# IRS990-FederalGrantAuditPerformedInd                                                   95658
# IRS990-LessRentalExpensesGrp-RealAmt                                                   94368
# IRS990-FundraisingGrossIncomeAmt                                                       81571
# IRS990-FundraisingDirectExpensesAmt                                                    82087
# IRS990-NetIncmFromFundraisingEvtGrp-TotalRevenueColumnAmt                              75040
# IRS990-NetIncmFromFundraisingEvtGrp-ExclusionAmt                                       88396
# IRS990-PayrollTaxesGrp-FundraisingAmt                                                  86823
# IRS990-AllAffiliatesIncludedInd                                                        90559
# IRS990-InvestTaxExemptBondsInd                                                         89140
# IRS990-EscrowAccountInd                                                                89152
# IRS990-OnBehalfOfIssuerInd                                                             89159
# IRS990-TransactionWithControlEntInd                                                    81241
# IRS990-Form990TFiledInd                                                                85657
# IRS990-OrgFiledInLieuOfForm1041Ind                                                     90854
# IRS990-LicensedMoreThanOneStateInd                                                     90649
# IRS990-ProgramServiceRevenueGrp-ExclusionAmt                                           97481
# IRS990-IncmFromInvestBondProceedsGrp-TotalRevenueColumnAmt                             87579
# IRS990-RoyaltiesRevenueGrp-TotalRevenueColumnAmt                                       86494
# IRS990-RoyaltiesRevenueGrp-ExclusionAmt                                                98157
# IRS990-OtherRevenueMiscGrp-UnrelatedBusinessRevenueAmt                                 97859
# IRS990-FeesForServicesProfFundraising-TotalAmt                                         86577
# IRS990-InventoriesForSaleOrUseGrp-EOYAmt                                               80824
# IRS990-InvestmentsProgramRelatedGrp-EOYAmt                                             86423
# IRS990-IntangibleAssetsGrp-EOYAmt                                                      85739
# IRS990-ProgSrvcAccomActyOtherGrp-ExpenseAmt                                            93865
# IRS990-ProgSrvcAccomActyOtherGrp-Desc                                                  92431
# IRS990-TotalOtherProgSrvcExpenseAmt                                                    92056
# IRS990-OtherWebsiteInd                                                                 92434
# IRS990-NoncashContributionsAmt                                                         90739
# IRS990-ContriRptFundraisingEventAmt                                                    90498
# IRS990-PensionPlanContributionsGrp-FundraisingAmt                                      95187
# IRS990-AdvertisingGrp-ManagementAndGeneralAmt                                          86201
# IRS990-InformationTechnologyGrp-ProgramServicesAmt                                     88449
# IRS990-InformationTechnologyGrp-ManagementAndGeneralAmt                                88460
# IRS990-InformationTechnologyGrp-FundraisingAmt                                         95078
# IRS990-TravelGrp-FundraisingAmt                                                        91779
# IRS990-ConferencesMeetingsGrp-FundraisingAmt                                           94690
# IRS990-DepreciationDepletionGrp-FundraisingAmt                                         92768
# IRS990-DonatedServicesAndUseFcltsAmt                                                   98339
# IRS990-TypeOfOrganizationAssocInd                                                      97452
# IRS990-Form8282FiledCnt                                                                92819
# IRS990-InfoInScheduleOPartIXInd                                                        89467
# IRS990-GrantsToDomesticIndividualsGrp-ProgramServicesAmt                               92498
# IRS990-InitiationFeesAndCapContriAmt                                                   99020
# IRS990-GrossReceiptsForPublicUseAmt                                                    99095
# IRS990-Form990PartVIISectionAGrp-HighestCompensatedEmployeeInd                         92654
# IRS990-ContractorCompensationGrp-ContractorName-BusinessName-BusinessNameLine1Txt      93928
# IRS990-ContractorCompensationGrp-ContractorAddress-USAddress-AddressLine1Txt           92621
# IRS990-ContractorCompensationGrp-ContractorAddress-USAddress-CityNm                    92621
# IRS990-ContractorCompensationGrp-ContractorAddress-USAddress-StateAbbreviationCd       92621
# IRS990-ContractorCompensationGrp-ContractorAddress-USAddress-ZIPCd                     92621
# IRS990-ContractorCompensationGrp-ServicesDesc                                          92550
# IRS990-ContractorCompensationGrp-CompensationAmt                                       92569
# IRS990-ProgramServiceRevenueGrp-UnrelatedBusinessRevenueAmt                            97312
# IRS990-CostOfGoodsSoldAmt                                                              90606
# IRS990-NetIncomeOrLossGrp-UnrelatedBusinessRevenueAmt                                  98741
# IRS990-InventoriesForSaleOrUseGrp-BOYAmt                                               88570
# IRS990-ProgSrvcAccomActyOtherGrp-RevenueAmt                                            97252
# IRS990-TotalOtherProgSrvcRevenueAmt                                                    96067
# IRS990-WrittenPolicyOrProcedureInd                                                     98489
# IRS990-ContractorCompensationGrp-ContractorName-PersonNm                               97999
# IRS990-NetIncomeOrLossGrp-ExclusionAmt                                                 98060
# IRS990-EscrowAccountLiabilityGrp-BOYAmt                                                95758
# IRS990-EscrowAccountLiabilityGrp-EOYAmt                                                95785
# IRS990-CapStkTrPrinCurrentFundsGrp-BOYAmt                                              93038
# IRS990-CapStkTrPrinCurrentFundsGrp-EOYAmt                                              93068
# IRS990-PdInCapSrplsLandBldgEqpFundGrp-BOYAmt                                           93558
# IRS990-PdInCapSrplsLandBldgEqpFundGrp-EOYAmt                                           93572
# IRS990-OtherInd                                                                        98829
# IRS990-FeesForServicesManagementGrp-ProgramServicesAmt                                 95391
# IRS990-TypeOfOrganizationTrustInd                                                      98052
# IRS990-InfoInScheduleOPartVIIInd                                                       97956
# IRS990-FeesForServicesManagementGrp-ManagementAndGeneralAmt                            94156
# IRS990-PriorPeriodAdjustmentsAmt                                                       94696
# IRS990-InfoInScheduleOPartXIIInd                                                       89590
# IRS990-NetGainOrLossInvestmentsGrp-RelatedOrExemptFuncIncomeAmt                        94148
# IRS990-FeesForServicesAccountingGrp-FundraisingAmt                                     94394
# IRS990-GrantAmt                                                                        86255
# IRS990-ProgSrvcAccomActy3Grp-GrantAmt                                                  97426
# IRS990-LessCostOthBasisSalesExpnssGrp-OtherAmt                                         94647
# IRS990-ForeignCountryCd                                                                99083
# IRS990-FeesForServicesManagementGrp-FundraisingAmt                                     98314
# IRS990-OwnWebsiteInd                                                                   96393
# IRS990-InterestGrp-ManagementAndGeneralAmt                                             90805
# IRS990-InterestGrp-FundraisingAmt                                                      97414
# IRS990-FeesForServicesProfFundraising-FundraisingAmt                                   97839
# IRS990-CompDisqualPersonsGrp-ProgramServicesAmt                                        98247
# IRS990-CompDisqualPersonsGrp-ManagementAndGeneralAmt                                   98470
# IRS990-CompDisqualPersonsGrp-FundraisingAmt                                            98934
# IRS990-FeesForSrvcInvstMgmntFeesGrp-ProgramServicesAmt                                 98017
# IRS990-FeesForSrvcInvstMgmntFeesGrp-FundraisingAmt                                     98928
# IRS990-Form990PartVIISectionAGrp-KeyEmployeeInd                                        94931
# IRS990-TotalOtherProgSrvcGrantAmt                                                      97303
# IRS990-BooksInCareOfDetail-USAddress-AddressLine2Txt                                   98825
# IRS990-InvestmentIncomeGrp-UnrelatedBusinessRevenueAmt                                 97509
# IRS990-IncmFromInvestBondProceedsGrp-RelatedOrExemptFuncIncomeAmt                      99249
# IRS990-IncmFromInvestBondProceedsGrp-UnrelatedBusinessRevenueAmt                       99300
# IRS990-IncmFromInvestBondProceedsGrp-ExclusionAmt                                      99152
# IRS990-RoyaltiesRevenueGrp-RelatedOrExemptFuncIncomeAmt                                98969
# IRS990-RoyaltiesRevenueGrp-UnrelatedBusinessRevenueAmt                                 99234
# IRS990-GrossAmountSalesAssetsGrp-OtherAmt                                              94861
# IRS990-NetGainOrLossInvestmentsGrp-UnrelatedBusinessRevenueAmt                         99310
# IRS990-BenefitsToMembersGrp-ProgramServicesAmt                                         98167
# IRS990-FeesForServicesLegalGrp-FundraisingAmt                                          97559
# IRS990-FeesForServicesLobbyingGrp-ProgramServicesAmt                                   98668
# IRS990-FeesForServicesLobbyingGrp-FundraisingAmt                                       99357
# IRS990-RoyaltiesGrp-ProgramServicesAmt                                                 99006
# IRS990-RoyaltiesGrp-ManagementAndGeneralAmt                                            99368
# IRS990-RoyaltiesGrp-FundraisingAmt                                                     99417
# IRS990-PymtTravelEntrtnmntPubOfclGrp-ProgramServicesAmt                                99233
# IRS990-PymtTravelEntrtnmntPubOfclGrp-ManagementAndGeneralAmt                           99320
# IRS990-PymtTravelEntrtnmntPubOfclGrp-FundraisingAmt                                    99400
# IRS990-RcvblFromDisqualifiedPrsnGrp-BOYAmt                                             96793
# IRS990-GrantsPayableGrp-BOYAmt                                                         95605
# IRS990-GrantsPayableGrp-EOYAmt                                                         95608
# IRS990-InvestmentExpenseAmt                                                            98758
# IRS990-GrossRentsGrp-PersonalAmt                                                       99262
# IRS990-LessRentalExpensesGrp-PersonalAmt                                               99445
# IRS990-NetIncmFromFundraisingEvtGrp-UnrelatedBusinessRevenueAmt                        99330
# IRS990-NetIncomeFromGamingGrp-ExclusionAmt                                             98569
# IRS990-PoliciesReferenceChaptersInd                                                    96954
# IRS990-InfoInScheduleOPartVInd                                                         98940
# IRS990-InfoInScheduleOPartXInd                                                         99415
# IRS990-Form8886TFiledInd                                                               99718
# IRS990-NondeductibleContriDisclInd                                                     98067
# IRS990-Form990PartVIISectionAGrp-FormerOfcrDirectorTrusteeInd                          98488
# IRS990-AddressChangeInd                                                                97598
# IRS990-BooksInCareOfDetail-ForeignAddress-AddressLine1Txt                              99880
# IRS990-BooksInCareOfDetail-ForeignAddress-CityNm                                       99885
# IRS990-BooksInCareOfDetail-ForeignAddress-CountryCd                                    99880
# IRS990-BooksInCareOfDetail-ForeignAddress-ForeignPostalCd                              99904
# IRS990-TaxExemptInterestAmt                                                            99908
# IRS990-GroupExemptionNum                                                               98109
# IRS990-IntangibleAssetsGrp-BOYAmt                                                      94206
# IRS990-ProgSrvcAccomActyOtherGrp-GrantAmt                                              98313
# IRS990-MethodOfAccountingOtherInd                                                      98732
# IRS990-USAddress-AddressLine2Txt                                                       99346
# IRS990-BooksInCareOfDetail-BusinessName-BusinessNameLine2Txt                           99559
# IRS990-AcctCompileOrReviewBasisGrp-ConsolidatedBasisFinclStmtInd                       99331
# IRS990-FSAuditedBasisGrp-ConsolAndSepBasisFinclStmtInd                                 98578
# IRS990-InitialReturnInd                                                                99411
# IRS990-Form990PartVIISectionAGrp-InstitutionalTrusteeInd                               99177
# IRS990-Form720FiledInd                                                                 99852
# IRS990-ContractorCompensationGrp-ContractorAddress-ForeignAddress-AddressLine1Txt      99785
# IRS990-ContractorCompensationGrp-ContractorAddress-ForeignAddress-CityNm               99795
# IRS990-ContractorCompensationGrp-ContractorAddress-ForeignAddress-ProvinceOrStateNm    99880
# IRS990-ContractorCompensationGrp-ContractorAddress-ForeignAddress-CountryCd            99785
# IRS990-ContractorCompensationGrp-ContractorAddress-ForeignAddress-ForeignPostalCd      99877
# AddressLine2Txt                                                                        99577
# IRS990-TypeOfOrganizationOtherInd                                                      98718
# IRS990-OtherOrganizationDsc                                                            99058
# IRS990-Form990PartVIISectionAGrp-BusinessName-BusinessNameLine2Txt                     99928
# IRS990-ForeignAddress-AddressLine1Txt                                                  99893
# IRS990-ForeignAddress-AddressLine2Txt                                                  99990
# IRS990-ForeignAddress-CityNm                                                           99897
# IRS990-ForeignAddress-CountryCd                                                        99893
# IRS990-NetRentalIncomeOrLossGrp-UnrelatedBusinessRevenueAmt                            98455
# IRS990-FinalReturnInd                                                                  99724
# IRS990-ContractTerminationInd                                                          99528
# IRS990-AcctCompileOrReviewBasisGrp                                                     99932
# IRS990-FSAuditedBasisGrp                                                               99881
# IRS990-JointCostsInd                                                                   99511
# IRS990-TotalJointCostsGrp-TotalAmt                                                     99732
# IRS990-TotalJointCostsGrp-ProgramServicesAmt                                           99853
# IRS990-TotalJointCostsGrp-ManagementAndGeneralAmt                                      99867
# IRS990-TotalJointCostsGrp-FundraisingAmt                                               99856
# IRS990-ContractorCompensationGrp-ContractorAddress                                     99767
# IRS990-MembersAndShrGrossIncomeAmt                                                     99602
# IRS990-OtherSourcesGrossIncomeAmt                                                      99618
# SSN                                                                                    99974
# IRS990-BooksInCareOfDetail-ForeignAddress-ProvinceOrStateNm                            99942
# IRS990-AuditedFinancialStmtAttInd                                                      99440
# IRS990-AcctCompileOrReviewBasisGrp-ConsolAndSepBasisFinclStmtInd                       99802
# IRS990-NetIncomeFromGamingGrp-UnrelatedBusinessRevenueAmt                              99337
# IRS990-ContractorCompensationGrp-ContractorAddress-USAddress-AddressLine2Txt           99844
# IRS990-PrincipalOfcrBusinessName-BusinessNameLine2Txt                                  99962
# IRS990-StateRequiredReservesAmt                                                        99947
# IRS990-ReservesMaintainedAmt                                                           99949
# IRS990-ActivityCd                                                                      99919
# DisasterReliefTxt                                                                      99904
# CountryCd                                                                              99898
# IRS990-ProgSrvcAccomActy2Grp-ActivityCd                                                99971
# IRS990-ContractorCompensationGrp-ContractorName-BusinessName-BusinessNameLine2Txt      99969
# IRS990-ProgSrvcAccomActy2Grp                                                           99988
# IRS990-ProgSrvcAccomActy3Grp                                                           99996
# IRS990-LegalDomicileCountryCd                                                          99956
# ProvinceOrStateNm                                                                      99944
# ForeignPostalCd                                                                        99921
# IRS990-DoingBusinessAsName-BusinessNameLine2Txt                                        99961
# IRS990-SpecialConditionDesc                                                            99932
# IRS990-ProgSrvcAccomActyOtherGrp-ActivityCd                                            99995
# IRS990-ForeignAddress-ProvinceOrStateNm                                                99940
# IRS990-ForeignAddress-ForeignPostalCd                                                  99937
# IRS990-Organization4947a1NotPFInd                                                      99971
# IRS990-ProgSrvcAccomActy3Grp-ActivityCd                                                99983
# IRS990-GrossRentsGrp                                                                   99998
# IRS990-BooksInCareOfDetail-ForeignAddress-AddressLine2Txt                              99996
# IRS990-LessCostOthBasisSalesExpnssGrp                                                  99996
# IRS990-ContractorCompensationGrp-ContractorAddress-ForeignAddress-AddressLine2Txt      99995
# IRS990-AccountsReceivableGrp                                                           99999
# dtype: int64

# %% [markdown]
# The final step is to export to csv files.

# %%
df_990.to_csv('C:\\Users\\hangl\\Documents\\Summer RA\\Non-profit\\IRS\\2014_IRS990_part2.csv', index= False)

# %% [markdown]
# ### Collecting ReturnVersion and EIN

# %% [markdown]
# As different version of tax return will include different columns names, this code will get you the EIN and ReturnVersion and store in csv files so that you can merge with current data.

# %%
sitename = {'name':'http://www.irs.gov/efile'}
directory = 'C:\\Users\\hangl\\Documents\\Summer RA\\Non-profit\\IRS\\XML_2018\\' # Stating the year and directory where you store XML files
listReturnVersionEIN = [] # Create empty dictionary to store data
files = os.listdir(directory)
for fileName in files:
    dictData = {}
    tree = etree.parse(directory+fileName)
    root = tree.getroot()
    dictData.update({'ReturnVersion':root.attrib['returnVersion']}) # Getting ReturnVersion
    node = root.find('name:ReturnHeader/name:Filer/name:EIN',sitename)# Getting only EIN under ReturnHeader section
    text = ''
    if node.text != None :
            text = str(node.text.encode('utf8')).replace('b','').replace("'","")
    dictData.update({'EIN':text})
    listReturnVersionEIN.append(dictData)

# %%
df_ReturnVersionEIN = pd.DataFrame(listReturnVersionEIN) # Convert Python dictionary to Dataframe

# %%
# Saved as CSV file
df_ReturnVersionEIN.to_csv('C:\\Users\\hangl\\Documents\\Summer RA\\Non-profit\\IRS\\2018_ReturnVersionEIN.csv', index= False)
